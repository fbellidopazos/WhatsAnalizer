# %%
from whatsParser import *
users=getUsers("text/sofia.txt")
print(users)
users[1].total_messages()
user=users[2]
# Out:
# [None, Fernando Bellido Pazos, Sofia Lopez]

# %%
user.daily_quantity_analysis()

# %%
user.hour_analysis()

# %%
user.weekday_analysis()
